# %%
#parsing JSON:

# %%
import json
from urllib.request import urlopen

# %%
def getCountry(ipAddress):
    response = urlopen('http://api.ipstack.com/'+ipAddress+'?access_key=c08e0e2b8560f10faaf1c0750f1acb20').read().decode('utf-8')
    responseJson = json.loads(response)
    return responseJson.get('country_code')

print(getCountry('161.185.160.93'))
# Out:
# US

# %% [markdown]
# # create a basic script that crawls wikipedia

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import json
import datetime
import rand

# %%
random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).findAll('a',href=re.compile('^(/wiki/)((?!:).)*$'))

# %%
def getHistoryIPs(pageUrl):
    #Format of revision history pages is: 
    #http://en.wikipedia.org/w/index.php?title=Title_in_URL&action=history
    pageUrl = pageUrl.replace('/wiki/', '')
    historyUrl = 'http://en.wikipedia.org/w/index.php?title={}&action=history'.format(pageUrl)
    print('history url is: {}'.format(historyUrl))
    html = urlopen(historyUrl)
    bs = BeautifulSoup(html, 'html.parser')
    #finds only the links with class "mw-anonuserlink" which has IP addresses 
    #instead of usernames
    ipAddresses = bs.findAll('a', {'class':'mw-anonuserlink'})
    addressList = set()
    for ipAddress in ipAddresses:
        addressList.add(ipAddress.get_text())
    return addressList

links = getLinks('/wiki/Python_(programming_language)')

while(len(links) > 0):
    for link in links:
        print('-'*20)
        historyIPs = getHistoryIPs(link.attrs['href'])
        for historyIP in historyIPs:
            print(historyIP)
newLink = links[random.randint(0, len(links)-1)].attrs['href']
links = getLinks(newLink)
# Out:
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Programming_paradigm&action=history
# 2001:171b:226c:d550:d837:b286:5892:7f22
# 106.203.236.74
# 36.255.87.160
# 106.215.120.243
# 85.107.66.187
# 2402:8100:3a0f:9ac:c1c2:35c3:2d9a:dff6
# 51.39.3.208
# 172.115.220.47
# 223.25.63.145
# 5.239.162.101
# 2409:4042:e8f:8d39:b50c:f4ca:91b8:eb9d
# 2806:108e:d:bd2c:a577:db4f:2867:2b5c
# 107.190.108.84
# 2806:1016:d:54b6:8950:4501:c00b:507a
# 2405:201:2009:80b0:41bc:366f:a49c:52f2
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Multi-paradigm_programming_language&action=history
# 75.139.254.117
# 98.197.198.46
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Object-oriented_programming&action=history
# 103.243.67.86
# 117.221.205.234
# 49.36.100.23
# 12.183.178.250
# 81.131.103.252
# 71.32.81.247
# 163.116.205.116
# 2409:4055:9b:42fd:558:fb68:5d55:7809
# 131.119.15.14
# 98.4.112.204
# 147.161.161.101
# 216.21.135.198
# 136.148.37.28
# 106.1.248.137
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Procedural_programming&action=history
# 174.90.223.214
# 216.225.124.244
# 2601:2c3:867f:e810:5b9b:58e7:b427:e352
# 162.208.181.210
# 66.76.37.82
# 2600:1000:b045:9be1:67c4:f788:c2fb:461d
# 2607:fea8:9560:8ae:e155:3e6f:7747:5544
# 112.79.118.122
# 151.255.244.223
# 83.173.200.121
# 117.220.135.30
# 2001:44c8:45d2:11cd:1:0:2e69:c996
# 112.134.214.53
# 194.214.56.66
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Imperative_programming&action=history
# 2a02:c7f:c28c:f400:e510:1e3e:d3d2:a21e
# 2603:6010:df00:21d5:8dbc:53ba:9aa1:6267
# 189.204.196.201
# 207.255.75.92
# 2405:204:a3a7:c3bd::f0b:a0ac
# 2001:4454:38f:fc00:c8f1:b67e:da95:ab6f
# 173.225.40.198
# 49.207.196.35
# 74.134.74.248
# 223.24.167.37
# 117.207.179.184
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Functional_programming&action=history
# 2600:6c4a:4d7f:e999:d21:9ad5:a5e4:e20d
# 104.152.255.71
# 105.12.5.186
# 190.21.59.10
# 2804:14c:1c2:821c:4970:1293:d1dc:3f00
# 134.204.220.36
# 2607:fea8:2363:8f00:a000:dce0:5c45:2642
# 2607:fea8:235f:9730::1232
# 109.125.120.234
# 23.121.65.56
# 2a01:e0a:2cb:ee10:2dc7:7cf3:378f:f729
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Structured_programming&action=history
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-a72f1297707e> in <module>
#      20     for link in links:
#      21         print('-'*20)
# ---> 22         historyIPs = getHistoryIPs(link.attrs['href'])
#      23         for historyIP in historyIPs:
#      24             print(historyIP)
#
# <ipython-input-33-a72f1297707e> in getHistoryIPs(pageUrl)
#       5     historyUrl = 'http://en.wikipedia.org/w/index.php?title={}&action=history'.format(pageUrl)
#       6     print('history url is: {}'.format(historyUrl))
# ----> 7     html = urlopen(historyUrl)
#       8     bs = BeautifulSoup(html, 'html.parser')
#       9     #finds only the links with class "mw-anonuserlink" which has IP addresses
#
# c:\python\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\python\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# c:\python\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# c:\python\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# c:\python\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# c:\python\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# c:\python\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# c:\python\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# c:\python\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# c:\python\lib\urllib\request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# c:\python\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1315             try:
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
#
# c:\python\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# c:\python\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# c:\python\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# c:\python\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# c:\python\lib\http\client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# c:\python\lib\http\client.py in connect(self)
#    1382             "Connect to a host on a given (SSL) port."
#    1383
# -> 1384             super().connect()
#    1385
#    1386             if self._tunnel_host:
#
# c:\python\lib\http\client.py in connect(self)
#     926         """Connect to the host and port specified in __init__."""
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     930
#
# c:\python\lib\socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# KeyboardInterrupt:

# %%
 links = getLinks('/wiki/Python_(programming_language)')

while(len(links) > 0):
    for link in links:
        print('-'*20)
        historyIPs = getHistoryIPs(link.attrs["href"])
        for historyIP in historyIPs:
            country = getCountry(historyIP)
            if country is not None:
                print('{} is from {}'.format(historyIP, country))
    newLink = links[random.randint(0, len(links)-1)].attrs['href']
    links = getLinks(newLink)
# Out:
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Programming_paradigm&action=history
# 2001:171b:226c:d550:d837:b286:5892:7f22 is from CH
# 106.203.236.74 is from IN
# 36.255.87.160 is from IN
# 106.215.120.243 is from IN
# 85.107.66.187 is from TR
# 2402:8100:3a0f:9ac:c1c2:35c3:2d9a:dff6 is from IN
# 51.39.3.208 is from SA
# 172.115.220.47 is from US
# 223.25.63.145 is from PH
# 5.239.162.101 is from IR
# 2409:4042:e8f:8d39:b50c:f4ca:91b8:eb9d is from IN
# 2806:108e:d:bd2c:a577:db4f:2867:2b5c is from MX
# 107.190.108.84 is from CA
# 2806:1016:d:54b6:8950:4501:c00b:507a is from MX
# 2405:201:2009:80b0:41bc:366f:a49c:52f2 is from IN
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Multi-paradigm_programming_language&action=history
# 75.139.254.117 is from US
# 98.197.198.46 is from US
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Object-oriented_programming&action=history
# 103.243.67.86 is from AU
# 117.221.205.234 is from IN
# 49.36.100.23 is from IN
# 12.183.178.250 is from US
# 81.131.103.252 is from GB
# 71.32.81.247 is from US
# 163.116.205.116 is from IN
# 2409:4055:9b:42fd:558:fb68:5d55:7809 is from IN
# 131.119.15.14 is from US
# 98.4.112.204 is from US
# 147.161.161.101 is from AE
# 216.21.135.198 is from CA
# 136.148.37.28 is from GB
# 106.1.248.137 is from TW
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Procedural_programming&action=history
# 174.90.223.214 is from CA
# 216.225.124.244 is from US
# 2601:2c3:867f:e810:5b9b:58e7:b427:e352 is from US
# 162.208.181.210 is from CA
# 66.76.37.82 is from US
# 2600:1000:b045:9be1:67c4:f788:c2fb:461d is from US
# 2607:fea8:9560:8ae:e155:3e6f:7747:5544 is from CA
# 112.79.118.122 is from IN
# 151.255.244.223 is from SA
# 83.173.200.121 is from CH
# 117.220.135.30 is from IN
# 2001:44c8:45d2:11cd:1:0:2e69:c996 is from TH
# 112.134.214.53 is from LK
# 194.214.56.66 is from FR
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Imperative_programming&action=history
# 2a02:c7f:c28c:f400:e510:1e3e:d3d2:a21e is from GB
# 2603:6010:df00:21d5:8dbc:53ba:9aa1:6267 is from US
# 189.204.196.201 is from MX
# 207.255.75.92 is from US
# 2405:204:a3a7:c3bd::f0b:a0ac is from IN
# 2001:4454:38f:fc00:c8f1:b67e:da95:ab6f is from PH
# 173.225.40.198 is from US
# 49.207.196.35 is from IN
# 74.134.74.248 is from US
# 223.24.167.37 is from TH
# 117.207.179.184 is from IN
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Functional_programming&action=history
# 2600:6c4a:4d7f:e999:d21:9ad5:a5e4:e20d is from US
# 104.152.255.71 is from US
# 105.12.5.186 is from ZA
# 190.21.59.10 is from CL
# 2804:14c:1c2:821c:4970:1293:d1dc:3f00 is from BR
# 134.204.220.36 is from US
# 2607:fea8:2363:8f00:a000:dce0:5c45:2642 is from CA
# 2607:fea8:235f:9730::1232 is from CA
# 109.125.120.234 is from DE
# 23.121.65.56 is from US
# 2a01:e0a:2cb:ee10:2dc7:7cf3:378f:f729 is from FR
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Structured_programming&action=history
# 165.82.134.144 is from US
# 64.119.192.201 is from BB
# 206.214.57.47 is from US
# 83.223.241.43 is from PT
# 41.89.61.3 is from KE
# 2401:4900:c16:df76:13e:4e10:599a:642e is from IN
# 103.164.47.189 is from IN
# 76.8.32.203 is from BM
# 186.112.199.10 is from CO
# 223.196.166.69 is from IN
# 2409:4051:291:a148:159a:ee30:ad1b:2179 is from IN
# 156.199.200.186 is from EG
# 2600:8805:a981:4300:65d3:9258:af92:d91c is from US
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Reflective_programming&action=history
# 95.60.233.218 is from ES
# 2601:444:8280:6880:b0c0:1c65:8627:243 is from US
# 2409:4064:4db3:5f54::13c8:b209 is from IN
# 2804:14d:3291:8807::2 is from BR
# 194.96.27.238 is from AT
# 2600:1700:87d0:5fd0:ac5c:5d73:f9a6:6fe2 is from US
# 49.180.136.136 is from AU
# 94.21.10.204 is from HU
# 2804:14d:72a3:c4:6d48:d3fb:77ea:5e3 is from BR
# 172.72.221.49 is from US
# 174.88.46.109 is from CA
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Software_design&action=history
# 63.143.93.92 is from JM
# 122.44.29.104 is from KR
# 121.131.23.77 is from KR
# 2401:4900:2341:c5d9:68f5:3a1a:5871:4ca2 is from IN
# 207.231.83.190 is from US
# 86.3.131.2 is from GB
# 47.15.239.143 is from IN
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Guido_van_Rossum&action=history
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Software_developer&action=history
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Python_Software_Foundation&action=history
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Software_release_life_cycle&action=history
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Software_release_life_cycle#Beta&action=history
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Type_system&action=history
# --------------------
# history url is: http://en.wikipedia.org/w/index.php?title=Duck_typing&action=history
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-9d564a766cb6> in <module>
#       6        historyIPs = getHistoryIPs(link.attrs["href"])
#       7        for historyIP in historyIPs:
# ----> 8            country = getCountry(historyIP)
#       9            if country is not None:
#      10                print('{} is from {}'.format(historyIP, country))
#
# <ipython-input-35-abce54b29058> in getCountry(ipAddress)
#       1 def getCountry(ipAddress):
# ----> 2     response = urlopen('http://api.ipstack.com/'+ipAddress+'?access_key=c08e0e2b8560f10faaf1c0750f1acb20').read().decode('utf-8')
#       3     responseJson = json.loads(response)
#       4     return responseJson.get('country_code')
#       5
#
# c:\python\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\python\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# c:\python\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# c:\python\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# c:\python\lib\urllib\request.py in http_open(self, req)
#    1343
#    1344     def http_open(self, req):
# -> 1345         return self.do_open(http.client.HTTPConnection, req)
#    1346
#    1347     http_request = AbstractHTTPHandler.do_request_
#
# c:\python\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1315             try:
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
#
# c:\python\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# c:\python\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# c:\python\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# c:\python\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# c:\python\lib\http\client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# c:\python\lib\http\client.py in connect(self)
#     926         """Connect to the host and port specified in __init__."""
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     930
#
# c:\python\lib\socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# KeyboardInterrupt:
